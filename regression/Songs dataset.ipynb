# %%
# %pip install numpy
# %pip install torch
# %pip install pandas
# %pip install scikit-learn

import numpy as np
import torch
import pandas as pd
import sklearn
import random

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
# Out:
# Requirement already satisfied: numpy in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (2.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (2.8.0)
# Requirement already satisfied: filelock in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# %pip install mlxtend
# %pip install onnxmltools
# %pip install onnxruntime
# %pip install skl2onnx

import matplotlib.pyplot as plt

from mlxtend.plotting import heatmap # to see the correlation matrix
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

## coefficient of determination
from sklearn.metrics import r2_score # this is the metric people want to see - what they are used to see
# Out:
# Requirement already satisfied: matplotlib in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mlxtend in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (3.9.4)
# Requirement already satisfied: joblib>=0.13.2 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->mlxtend) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: onnxmltools in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (1.14.0)
# Requirement already satisfied: numpy in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxmltools) (2.0.2)
# Requirement already satisfied: onnx in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxmltools) (1.19.1)
# Requirement already satisfied: protobuf>=4.25.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx->onnxmltools) (6.33.0)
# Requirement already satisfied: typing_extensions>=4.7.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx->onnxmltools) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx->onnxmltools) (0.5.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: onnxruntime in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (1.19.2)
# Requirement already satisfied: coloredlogs in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (2.0.2)
# Requirement already satisfied: packaging in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (25.0)
# Requirement already satisfied: protobuf in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (6.33.0)
# Requirement already satisfied: sympy in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (1.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from sympy->onnxruntime) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: skl2onnx in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (1.19.1)
# Requirement already satisfied: onnx>=1.2.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from skl2onnx) (1.19.1)
# Requirement already satisfied: scikit-learn>=1.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from skl2onnx) (1.6.1)
# Requirement already satisfied: numpy>=1.22 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx>=1.2.1->skl2onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx>=1.2.1->skl2onnx) (6.33.0)
# Requirement already satisfied: typing_extensions>=4.7.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx>=1.2.1->skl2onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx>=1.2.1->skl2onnx) (0.5.3)
# Requirement already satisfied: scipy>=1.6.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn>=1.1->skl2onnx) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn>=1.1->skl2onnx) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn>=1.1->skl2onnx) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install xgboost
import xgboost as xgb
# Out:
# Requirement already satisfied: xgboost in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (2.1.4)
# Requirement already satisfied: numpy in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from xgboost) (2.0.2)
# Requirement already satisfied: scipy in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from xgboost) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install mlxtend
# !pip install onnxmltools
# !pip install onnxruntime
# Out:
# Requirement already satisfied: mlxtend in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (3.9.4)
# Requirement already satisfied: joblib>=0.13.2 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->mlxtend) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: onnxmltools in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (1.14.0)
# Requirement already satisfied: numpy in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxmltools) (2.0.2)
# Requirement already satisfied: onnx in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxmltools) (1.19.1)
# Requirement already satisfied: protobuf>=4.25.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx->onnxmltools) (6.33.0)
# Requirement already satisfied: typing_extensions>=4.7.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx->onnxmltools) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx->onnxmltools) (0.5.3)
# Requirement already satisfied: onnxruntime in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (1.19.2)
# Requirement already satisfied: coloredlogs in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (2.0.2)
# Requirement already satisfied: packaging in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (25.0)
# Requirement already satisfied: protobuf in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (6.33.0)
# Requirement already satisfied: sympy in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnxruntime) (1.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from sympy->onnxruntime) (1.3.0)

# %%
# !pip install skl2onnx
# Out:
# Requirement already satisfied: skl2onnx in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (1.19.1)
# Requirement already satisfied: onnx>=1.2.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from skl2onnx) (1.19.1)
# Requirement already satisfied: scikit-learn>=1.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from skl2onnx) (1.6.1)
# Requirement already satisfied: numpy>=1.22 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx>=1.2.1->skl2onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx>=1.2.1->skl2onnx) (6.33.0)
# Requirement already satisfied: typing_extensions>=4.7.1 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx>=1.2.1->skl2onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from onnx>=1.2.1->skl2onnx) (0.5.3)
# Requirement already satisfied: scipy>=1.6.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn>=1.1->skl2onnx) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn>=1.1->skl2onnx) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/blasmorenolaguna/Documents/TODO/Coding/ClassificationAndRegression/.venv/lib/python3.9/site-packages (from scikit-learn>=1.1->skl2onnx) (3.6.0)

# %%
import onnxruntime as rt
import onnxmltools

from skl2onnx.common.data_types import FloatTensorType

# %%
## 0.001, 0.0001, 0.0003, 0.01, 0.03

batch_size    = 32
learning_rate = 0.001 ## 0.001 - We can play with this number making it bigger or smaller
N_Epochs      = 100 # Number of times we give the whole data set to the model

epsilon = 0.0001

# %%
# -------------- Read the data --------------

path_data = './dataset.csv'

songs_raw_data = pd.read_csv( path_data, delimiter="," )

# %%
songs_raw_data

# What we are going to predict is the popularity (last column), so we will have 10 columns as input
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                         track_name  popularity  duration_ms  explicit  \
# 0                           Comedy          73       230666     False
# 1                 Ghost - Acoustic          55       149610     False
# 2                   To Begin Again          57       210826     False
# 3       Can't Help Falling In Love          71       201933     False
# 4                          Hold On          82       198853     False
# ...                            ...         ...          ...       ...
# 113995         Sleep My Little Boy          21       384999     False
# 113996            Water Into Light          22       385000     False
# 113997              Miss Perfumado          22       271466     False
# 113998                     Friends          41       283893     False
# 113999                   Barbincor          22       241826     False
#
#         danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0              0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1              0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2              0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3              0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4              0.618  0.4430  ...    -9.681     1       0.0526        0.4690
# ...              ...     ...  ...       ...   ...          ...           ...
# 113995         0.172  0.2350  ...   -16.393     1       0.0422        0.6400
# 113996         0.174  0.1170  ...   -18.318     0       0.0401        0.9940
# 113997         0.629  0.3290  ...   -10.895     0       0.0420        0.8670
# 113998         0.587  0.5060  ...   -10.889     1       0.0297        0.3810
# 113999         0.526  0.4870  ...   -10.204     0       0.0725        0.6810
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000001    0.3580   0.7150   87.917               4
# 1               0.000006    0.1010   0.2670   77.489               4
# 2               0.000000    0.1170   0.1200   76.332               4
# 3               0.000071    0.1320   0.1430  181.740               3
# 4               0.000000    0.0829   0.1670  119.949               4
# ...                  ...       ...      ...      ...             ...
# 113995          0.928000    0.0863   0.0339  125.995               5
# 113996          0.976000    0.1050   0.0350   85.239               4
# 113997          0.000000    0.0839   0.7430  132.378               4
# 113998          0.000000    0.2700   0.4130  135.960               4
# 113999          0.000000    0.0893   0.7080   79.198               4
#
#         track_genre
# 0          acoustic
# 1          acoustic
# 2          acoustic
# 3          acoustic
# 4          acoustic
# ...             ...
# 113995  world-music
# 113996  world-music
# 113997  world-music
# 113998  world-music
# 113999  world-music
#
# [114000 rows x 21 columns]

# %%
songs_raw_data.shape
# Out:
# (114000, 11)

# %%
headers_list = songs_raw_data.columns.values.tolist()

headers_list
# Out:
# ['Unnamed: 0',
#  'track_id',
#  'artists',
#  'album_name',
#  'track_name',
#  'popularity',
#  'duration_ms',
#  'explicit',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'time_signature',
#  'track_genre']

# %%
# A list if we only wanted some columns
headers_list2 = ['duration_ms',
 'danceability',
 'energy',
 'key',
 'loudness',
 'mode',
 'speechiness',
 'acousticness',
 'instrumentalness',
 'tempo',
 'popularity']

print(headers_list2)
# Out:
# ['duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'tempo', 'popularity']

# %%
# Convert to numeric and ensure proper data type
data_for_corr = songs_raw_data[headers_list2].apply(pd.to_numeric, errors='coerce')
# Remove any rows with NaN values that might cause issues
data_for_corr = data_for_corr.dropna()
# Convert to numpy array with explicit float type
corr_data = data_for_corr.values.astype(float).T

cm = np.corrcoef(corr_data)
hm = heatmap(cm, row_names=headers_list2, column_names=headers_list2, figsize=(20,10))
plt.show()

# %%
songs_raw_data = songs_raw_data[headers_list2]
songs_raw_data
# Out:
#         duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0            230666         0.676  0.4610    1    -6.746     0       0.1430
# 1            149610         0.420  0.1660    1   -17.235     1       0.0763
# 2            210826         0.438  0.3590    0    -9.734     1       0.0557
# 3            201933         0.266  0.0596    0   -18.515     1       0.0363
# 4            198853         0.618  0.4430    2    -9.681     1       0.0526
# ...             ...           ...     ...  ...       ...   ...          ...
# 113995       384999         0.172  0.2350    5   -16.393     1       0.0422
# 113996       385000         0.174  0.1170    0   -18.318     0       0.0401
# 113997       271466         0.629  0.3290    0   -10.895     0       0.0420
# 113998       283893         0.587  0.5060    7   -10.889     1       0.0297
# 113999       241826         0.526  0.4870    1   -10.204     0       0.0725
#
#         acousticness  instrumentalness    tempo  popularity
# 0             0.0322          0.000001   87.917          73
# 1             0.9240          0.000006   77.489          55
# 2             0.2100          0.000000   76.332          57
# 3             0.9050          0.000071  181.740          71
# 4             0.4690          0.000000  119.949          82
# ...              ...               ...      ...         ...
# 113995        0.6400          0.928000  125.995          21
# 113996        0.9940          0.976000   85.239          22
# 113997        0.8670          0.000000  132.378          22
# 113998        0.3810          0.000000  135.960          41
# 113999        0.6810          0.000000   79.198          22
#
# [114000 rows x 11 columns]

# %%
## Convert Pandas to Numpy

songs_raw_data_np = songs_raw_data.to_numpy()

# %%
songs_raw_data_np[6, 1]
# Out:
# np.float64(0.407)

# %%
songs_raw_data_np.shape
# Out:
# (114000, 11)

# %%
# X is going to be all the columns but the last one
X = songs_raw_data_np[:, :-1]

# We don't convert the Y into integers since we are doing regression
y = songs_raw_data_np[:, 10:11]

# %%
print(X)
print(y)
# Out:
# [[2.30666e+05 6.76000e-01 4.61000e-01 ... 3.22000e-02 1.01000e-06
#   8.79170e+01]
#  [1.49610e+05 4.20000e-01 1.66000e-01 ... 9.24000e-01 5.56000e-06
#   7.74890e+01]
#  [2.10826e+05 4.38000e-01 3.59000e-01 ... 2.10000e-01 0.00000e+00
#   7.63320e+01]
#  ...
#  [2.71466e+05 6.29000e-01 3.29000e-01 ... 8.67000e-01 0.00000e+00
#   1.32378e+02]
#  [2.83893e+05 5.87000e-01 5.06000e-01 ... 3.81000e-01 0.00000e+00
#   1.35960e+02]
#  [2.41826e+05 5.26000e-01 4.87000e-01 ... 6.81000e-01 0.00000e+00
#   7.91980e+01]]
# [[73.]
#  [55.]
#  [57.]
#  ...
#  [22.]
#  [41.]
#  [22.]]

# %%
print(X.shape)

print(y.shape)
# Out:
# (114000, 10)
# (114000, 1)

# %%
# Random so we can run it 10 times and do an average
random_seed = int( 11)

# %%
# This function from sklearn is the one we will always use
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (91200, 10)
# (22800, 10)
# (91200, 1)
# (22800, 1)

# %%
y_test.dtype
# Out:
# dtype('float64')

# %%
type(y_test)
# Out:
# numpy.ndarray

# %%
## fix data type

X_train = X_train.astype(  np.float32  )
X_test  = X_test.astype(   np.float32  )
y_train = y_train.astype(  np.float32  )
y_test  = y_test.astype(   np.float32  )

# %%
X_train_tr = torch.from_numpy(X_train)
X_test_tr  = torch.from_numpy(X_test)
y_train_tr = torch.from_numpy(y_train)
y_test_tr  = torch.from_numpy(y_test)

# %%
x_means      = X_train_tr.mean(0, keepdim=True )

x_deviations = X_train_tr.std( 0, keepdim=True) + epsilon

# %%
x_means
# Out:
# tensor([[ 2.2792e+05,  5.6683e-01,  6.4121e-01,  5.3105e+00, -8.2620e+00,
#           6.3738e-01,  8.4699e-02,  3.1489e-01,  1.5620e-01,  1.2216e+02]])

# %%
x_deviations
# Out:
# tensor([[1.0501e+05, 1.7372e-01, 2.5176e-01, 3.5589e+00, 5.0313e+00, 4.8086e-01,
#          1.0554e-01, 3.3260e-01, 3.0983e-01, 2.9981e+01]])

# %%
X_train_tr.shape
# Out:
# torch.Size([91200, 10])

# %%
y_train_tr.shape
# Out:
# torch.Size([91200, 1])

# %%
train_ds = TensorDataset( X_train_tr, y_train_tr  )

# %%
train_dl = DataLoader( train_ds, batch_size, shuffle=True  )

# %%
train_dl

# %% [markdown]
# # NN Architectures

# %%
## Linear Regression

# This is actually a linear model but we are going to write it in the way
# of NN

class LinRegNet(nn.Module):
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()

        self.x_means      = x_means
        self.x_deviations = x_deviations

        self.linear1 = nn.Linear(10, 1)

    ## perform inference
    def forward(self, x):

        x = (x - self.x_means) / self.x_deviations

        y_pred = self.linear1(x)
        ## return torch.round( y_pred )
        return y_pred

# %%
# Added later, the rest of architectures

## MLP - Multi-layer perceptron

class MLP_Net(nn.Module):
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()

        self.x_means      = x_means
        self.x_deviations = x_deviations

        self.linear1 = nn.Linear(10, 8)
        self.act1    = nn.Sigmoid()
        self.linear2 = nn.Linear(8, 1)
        self.dropout = nn.Dropout(0.25)

    ## perform inference
    def forward(self, x):

        x = (x - self.x_means) / self.x_deviations

        x = self.linear1(x)
        x = self.act1(x)
        x = self.dropout(x)
        y_pred = self.linear2(x)

        ## return torch.round( y_pred )
        return y_pred

# %%
## Deep Learning with 2 hidden layers

class DL_Net(nn.Module):
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()

        self.x_means      = x_means
        self.x_deviations = x_deviations

        self.linear1 = nn.Linear(10, 10)
        self.act1    = nn.ReLU()
        self.linear2 = nn.Linear(10, 6)
        self.act2    = nn.ReLU()
        self.linear3 = nn.Linear(6, 1)
        self.dropout = nn.Dropout(0.25)

    ## perform inference
    def forward(self, x):

        x = (x - self.x_means) / self.x_deviations

        x = self.linear1(x)
        x = self.act1(x)
        x = self.linear2(x)
        x = self.act2(x)
        ## x = self.dropout(x)
        y_pred = self.linear3(x)

        ## return torch.round( y_pred )
        return y_pred

# %%
## Linear plus Nonlinear
## f1 + f2

# As a solution to the vanishing gradients -> weights become 0
# y = f(x) + x <- Kind of the idea of this architecture

class LinearPlusNonLinear_Net(nn.Module):
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()

        self.x_means      = x_means
        self.x_deviations = x_deviations

        ## F1
        self.f1_linear1 = nn.Linear(10, 1) # <- Linear one

        ## F2
        self.f2_linear1 = nn.Linear(10, 14) # <- MLP
        self.f2_act1    = nn.Sigmoid()
        self.f2_linear2 = nn.Linear(14, 1)


    ## perform inference
    def forward(self, x):

        x = (x - self.x_means) / self.x_deviations

        ## F1
        f1 = self.f1_linear1(x)

        ## F2 - this one is smaller, the one affecting more is F1
        f2 = self.f2_linear1(x)
        f2 = self.f2_act1(f2)
        f2 = self.f2_linear2(f2)

        y_pred = f1 + f2

        ## return torch.round( y_pred )
        return y_pred

# %%
## Linear + DL

class LinearPlusNonLinear_Net2(nn.Module):
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()

        self.x_means      = x_means
        self.x_deviations = x_deviations

        ## F1
        self.f1_linear1 = nn.Linear(10, 1) # <- Linear one

        ## F2
        self.f2_linear1 = nn.Linear(10, 10) # <- DL
        self.f2_act1    = nn.ReLU()

        self.f2_linear2 = nn.Linear(10, 6) # <- DL
        self.f2_act2    = nn.ReLU()

        self.f2_linear3 = nn.Linear(6, 1) # <- DL
        # In the last one we dont need Relu
        # In classification we would have used softmax


    ## perform inference
    def forward(self, x):

        x = (x - self.x_means) / self.x_deviations

        ## F1
        f1 = self.f1_linear1(x)

        ## F2 - this one is smaller, the one affecting more is F1
        f2 = self.f2_linear1(x)
        f2 = self.f2_act1(f2)

        f2 = self.f2_linear2(f2)
        f2 = self.f2_act2(f2)

        f2 = self.f2_linear3(f2)

        y_pred = f1 + f2

        ## return torch.round( y_pred )
        return y_pred

# %%
def training_loop( N_Epochs, model, loss_fn, opt  ):

    for epoch in range(N_Epochs):
        for xb, yb in train_dl:

            y_pred = model(xb)
            loss   = loss_fn(y_pred, yb) # + dont kill humans

            # This 3 lines do all the magic
            opt.zero_grad() # Clear the gradients of the optimizer
            loss.backward() # Calculate the derivatives for every weight
            opt.step()      # Update the weights using the derivatives

        if epoch % 20 == 0:
            print(epoch, "loss=", loss)

# %%
model = LinearPlusNonLinear_Net( x_means, x_deviations  )

opt     = torch.optim.Adam(    model.parameters(), lr=learning_rate ) # 11 features and 1 bias
loss_fn = F.mse_loss

training_loop(  N_Epochs, model, loss_fn, opt  )
# Out:
# 0 loss= tensor(569.8544, grad_fn=<MseLossBackward0>)
# 20 loss= tensor(415.3466, grad_fn=<MseLossBackward0>)
# 40 loss= tensor(465.7689, grad_fn=<MseLossBackward0>)
# 60 loss= tensor(476.6672, grad_fn=<MseLossBackward0>)
# 80 loss= tensor(421.7255, grad_fn=<MseLossBackward0>)

# %%
# EVALUATING

y_pred_test = model( X_test_tr )

# %%
y_pred_test.shape
# Out:
# torch.Size([22800, 1])

# %%
# from skn R square
print( "Testing R**2: ", r2_score(
                          y_test_tr.numpy(),            # real data
                          y_pred_test.detach().numpy()  # pred data
))

# Detatch from the computational graph is needed
# The real data has to ALWAYS be before the pred data
# If we get a negative number means that something went wrong
# The closer to 1 the better
# Out:
# Testing R**2:  0.0603601336479187

# %%
list_preds = []
list_reals = []

for i in range(len(X_test_tr)):
    print("************************************")
    print("pred, real")
    np_real =   y_test_tr[i].detach().numpy()
    np_pred = y_pred_test[i].detach().numpy()
    print(( np_pred  , np_real))
    list_preds.append(np_pred[0])
    list_reals.append(np_real[0])

# Iteracts and predicts the value printing it
# Out:
# ************************************
# pred, real
# (array([34.93018], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([32.125816], dtype=float32), array([27.], dtype=float32))
# ************************************
# pred, real
# (array([30.732153], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([34.392567], dtype=float32), array([7.], dtype=float32))
# ************************************
# pred, real
# (array([29.451942], dtype=float32), array([69.], dtype=float32))
# ************************************
# pred, real
# (array([33.205677], dtype=float32), array([1.], dtype=float32))
# ************************************
# pred, real
# (array([35.60196], dtype=float32), array([46.], dtype=float32))
# ************************************
# pred, real
# (array([28.026934], dtype=float32), array([58.], dtype=float32))
# ************************************
# pred, real
# (array([30.46938], dtype=float32), array([21.], dtype=float32))
# ************************************
# pred, real
# (array([34.012352], dtype=float32), array([47.], dtype=float32))
# ************************************
# pred, real
# (array([25.94458], dtype=float32), array([18.], dtype=float32))
# ************************************
# pred, real
# (array([28.023129], dtype=float32), array([50.], dtype=float32))
# ************************************
# pred, real
# (array([32.935642], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([19.854673], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([26.12611], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([37.7073], dtype=float32), array([29.], dtype=float32))
# ************************************
# pred, real
# (array([25.11515], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([28.571663], dtype=float32), array([22.], dtype=float32))
# ************************************
# pred, real
# (array([41.87701], dtype=float32), array([69.], dtype=float32))
# ************************************
# pred, real
# (array([32.622253], dtype=float32), array([41.], dtype=float32))
# ************************************
# pred, real
# (array([30.9031], dtype=float32), array([40.], dtype=float32))
# ************************************
# pred, real
# (array([35.996117], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([38.42816], dtype=float32), array([1.], dtype=float32))
# ************************************
# pred, real
# (array([36.33694], dtype=float32), array([47.], dtype=float32))
# ************************************
# pred, real
# (array([33.716805], dtype=float32), array([29.], dtype=float32))
# ************************************
# pred, real
# (array([36.752617], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([40.879818], dtype=float32), array([48.], dtype=float32))
# ************************************
# pred, real
# (array([36.027534], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([28.973988], dtype=float32), array([35.], dtype=float32))
# ************************************
# pred, real
# (array([34.92637], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([26.87876], dtype=float32), array([47.], dtype=float32))
# ************************************
# pred, real
# (array([30.84531], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.15174], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([36.01467], dtype=float32), array([48.], dtype=float32))
# ************************************
# pred, real
# (array([41.644947], dtype=float32), array([50.], dtype=float32))
# ************************************
# pred, real
# (array([38.627556], dtype=float32), array([82.], dtype=float32))
# ************************************
# pred, real
# (array([32.966938], dtype=float32), array([78.], dtype=float32))
# ************************************
# pred, real
# (array([31.123236], dtype=float32), array([46.], dtype=float32))
# ************************************
# pred, real
# (array([38.378685], dtype=float32), array([75.], dtype=float32))
# ************************************
# pred, real
# (array([39.43444], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([31.96483], dtype=float32), array([34.], dtype=float32))
# ************************************
# pred, real
# (array([35.246777], dtype=float32), array([39.], dtype=float32))
# ************************************
# pred, real
# (array([39.838543], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([35.030327], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([40.33727], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([29.624863], dtype=float32), array([79.], dtype=float32))
# ************************************
# pred, real
# (array([38.188988], dtype=float32), array([35.], dtype=float32))
# ************************************
# pred, real
# (array([30.918354], dtype=float32), array([4.], dtype=float32))
# ************************************
# pred, real
# (array([28.218172], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([33.37457], dtype=float32), array([80.], dtype=float32))
# ************************************
# pred, real
# (array([40.306587], dtype=float32), array([40.], dtype=float32))
# ************************************
# pred, real
# (array([24.485546], dtype=float32), array([1.], dtype=float32))
# ************************************
# pred, real
# (array([30.596289], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([34.79454], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([39.06189], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([35.353394], dtype=float32), array([90.], dtype=float32))
# ************************************
# pred, real
# (array([37.220093], dtype=float32), array([26.], dtype=float32))
# ************************************
# pred, real
# (array([39.308365], dtype=float32), array([81.], dtype=float32))
# ************************************
# pred, real
# (array([29.927063], dtype=float32), array([29.], dtype=float32))
# ************************************
# pred, real
# (array([28.684265], dtype=float32), array([22.], dtype=float32))
# ************************************
# pred, real
# (array([30.559004], dtype=float32), array([26.], dtype=float32))
# ************************************
# pred, real
# (array([41.393734], dtype=float32), array([46.], dtype=float32))
# ************************************
# pred, real
# (array([36.6282], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([26.085669], dtype=float32), array([13.], dtype=float32))
# ************************************
# pred, real
# (array([29.008976], dtype=float32), array([41.], dtype=float32))
# ************************************
# pred, real
# (array([39.09045], dtype=float32), array([78.], dtype=float32))
# ************************************
# pred, real
# (array([21.909489], dtype=float32), array([1.], dtype=float32))
# ************************************
# pred, real
# (array([35.100445], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([31.626795], dtype=float32), array([29.], dtype=float32))
# ************************************
# pred, real
# (array([32.16106], dtype=float32), array([34.], dtype=float32))
# ************************************
# pred, real
# (array([33.54894], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([35.100018], dtype=float32), array([1.], dtype=float32))
# ************************************
# pred, real
# (array([30.957783], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([44.741394], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([42.46666], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([22.346468], dtype=float32), array([35.], dtype=float32))
# ************************************
# pred, real
# (array([30.155233], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([29.727211], dtype=float32), array([19.], dtype=float32))
# ************************************
# pred, real
# (array([31.901352], dtype=float32), array([11.], dtype=float32))
# ************************************
# pred, real
# (array([28.679035], dtype=float32), array([7.], dtype=float32))
# ************************************
# pred, real
# (array([37.01794], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([31.566238], dtype=float32), array([21.], dtype=float32))
# ************************************
# pred, real
# (array([32.753693], dtype=float32), array([74.], dtype=float32))
# ************************************
# pred, real
# (array([35.819763], dtype=float32), array([29.], dtype=float32))
# ************************************
# pred, real
# (array([41.617485], dtype=float32), array([64.], dtype=float32))
# ************************************
# pred, real
# (array([28.027239], dtype=float32), array([59.], dtype=float32))
# ************************************
# pred, real
# (array([29.106375], dtype=float32), array([27.], dtype=float32))
# ************************************
# pred, real
# (array([35.55275], dtype=float32), array([14.], dtype=float32))
# ************************************
# pred, real
# (array([34.51929], dtype=float32), array([21.], dtype=float32))
# ************************************
# pred, real
# (array([34.776028], dtype=float32), array([63.], dtype=float32))
# ************************************
# pred, real
# (array([21.74713], dtype=float32), array([55.], dtype=float32))
# ************************************
# pred, real
# (array([32.697525], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([36.05616], dtype=float32), array([61.], dtype=float32))
# ************************************
# pred, real
# (array([24.61001], dtype=float32), array([21.], dtype=float32))
# ************************************
# pred, real
# (array([31.449299], dtype=float32), array([28.], dtype=float32))
# ************************************
# pred, real
# (array([36.56923], dtype=float32), array([32.], dtype=float32))
# ************************************
# pred, real
# (array([31.980114], dtype=float32), array([17.], dtype=float32))
# ************************************
# pred, real
# (array([13.613413], dtype=float32), array([36.], dtype=float32))
# ************************************
# pred, real
# (array([27.069075], dtype=float32), array([8.], dtype=float32))
# ************************************
# pred, real
# (array([41.520638], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([38.543045], dtype=float32), array([19.], dtype=float32))
# ************************************
# pred, real
# (array([31.012245], dtype=float32), array([17.], dtype=float32))
# ************************************
# pred, real
# (array([37.394905], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([37.08024], dtype=float32), array([60.], dtype=float32))
# ************************************
# pred, real
# (array([30.822594], dtype=float32), array([71.], dtype=float32))
# ************************************
# pred, real
# (array([34.835163], dtype=float32), array([3.], dtype=float32))
# ************************************
# pred, real
# (array([24.178247], dtype=float32), array([52.], dtype=float32))
# ************************************
# pred, real
# (array([34.823944], dtype=float32), array([58.], dtype=float32))
# ************************************
# pred, real
# (array([41.207916], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([34.268085], dtype=float32), array([55.], dtype=float32))
# ************************************
# pred, real
# (array([30.2434], dtype=float32), array([26.], dtype=float32))
# ************************************
# pred, real
# (array([35.29293], dtype=float32), array([38.], dtype=float32))
# ************************************
# pred, real
# (array([36.824688], dtype=float32), array([41.], dtype=float32))
# ************************************
# pred, real
# (array([39.138344], dtype=float32), array([50.], dtype=float32))
# ************************************
# pred, real
# (array([33.864773], dtype=float32), array([38.], dtype=float32))
# ************************************
# pred, real
# (array([28.292429], dtype=float32), array([57.], dtype=float32))
# ************************************
# pred, real
# (array([33.59488], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([38.976357], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([34.630165], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([39.968304], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([31.276861], dtype=float32), array([39.], dtype=float32))
# ************************************
# pred, real
# (array([43.370815], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([33.16449], dtype=float32), array([53.], dtype=float32))
# ************************************
# pred, real
# (array([29.549753], dtype=float32), array([18.], dtype=float32))
# ************************************
# pred, real
# (array([35.051964], dtype=float32), array([26.], dtype=float32))
# ************************************
# pred, real
# (array([29.341629], dtype=float32), array([25.], dtype=float32))
# ************************************
# pred, real
# (array([28.026566], dtype=float32), array([46.], dtype=float32))
# ************************************
# pred, real
# (array([36.08997], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([37.77327], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([27.181087], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([26.203226], dtype=float32), array([12.], dtype=float32))
# ************************************
# pred, real
# (array([34.960194], dtype=float32), array([26.], dtype=float32))
# ************************************
# pred, real
# (array([34.630142], dtype=float32), array([30.], dtype=float32))
# ************************************
# pred, real
# (array([33.478985], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([37.92995], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([37.150387], dtype=float32), array([35.], dtype=float32))
# ************************************
# pred, real
# (array([34.545372], dtype=float32), array([21.], dtype=float32))
# ************************************
# pred, real
# (array([28.942034], dtype=float32), array([20.], dtype=float32))
# ************************************
# pred, real
# (array([27.850351], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([37.299026], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([34.228035], dtype=float32), array([57.], dtype=float32))
# ************************************
# pred, real
# (array([32.719975], dtype=float32), array([40.], dtype=float32))
# ************************************
# pred, real
# (array([37.425106], dtype=float32), array([32.], dtype=float32))
# ************************************
# pred, real
# (array([27.91474], dtype=float32), array([32.], dtype=float32))
# ************************************
# pred, real
# (array([42.43875], dtype=float32), array([64.], dtype=float32))
# ************************************
# pred, real
# (array([28.262943], dtype=float32), array([29.], dtype=float32))
# ************************************
# pred, real
# (array([27.773914], dtype=float32), array([50.], dtype=float32))
# ************************************
# pred, real
# (array([32.611668], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([31.082872], dtype=float32), array([55.], dtype=float32))
# ************************************
# pred, real
# (array([22.05169], dtype=float32), array([62.], dtype=float32))
# ************************************
# pred, real
# (array([33.06409], dtype=float32), array([55.], dtype=float32))
# ************************************
# pred, real
# (array([33.903324], dtype=float32), array([58.], dtype=float32))
# ************************************
# pred, real
# (array([34.994644], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([33.958305], dtype=float32), array([40.], dtype=float32))
# ************************************
# pred, real
# (array([35.518276], dtype=float32), array([55.], dtype=float32))
# ************************************
# pred, real
# (array([35.02787], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([35.81992], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([41.375637], dtype=float32), array([34.], dtype=float32))
# ************************************
# pred, real
# (array([31.16438], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([36.384354], dtype=float32), array([19.], dtype=float32))
# ************************************
# pred, real
# (array([18.785164], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([39.54355], dtype=float32), array([41.], dtype=float32))
# ************************************
# pred, real
# (array([40.658566], dtype=float32), array([57.], dtype=float32))
# ************************************
# pred, real
# (array([34.77304], dtype=float32), array([66.], dtype=float32))
# ************************************
# pred, real
# (array([33.751553], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([30.675804], dtype=float32), array([32.], dtype=float32))
# ************************************
# pred, real
# (array([34.138096], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([27.765356], dtype=float32), array([29.], dtype=float32))
# ************************************
# pred, real
# (array([41.47408], dtype=float32), array([60.], dtype=float32))
# ************************************
# pred, real
# (array([32.478317], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([35.566734], dtype=float32), array([58.], dtype=float32))
# ************************************
# pred, real
# (array([35.22705], dtype=float32), array([52.], dtype=float32))
# ************************************
# pred, real
# (array([34.895763], dtype=float32), array([2.], dtype=float32))
# ************************************
# pred, real
# (array([31.044724], dtype=float32), array([32.], dtype=float32))
# ************************************
# pred, real
# (array([35.011475], dtype=float32), array([39.], dtype=float32))
# ************************************
# pred, real
# (array([31.022213], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([27.94796], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([34.94905], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([35.609585], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([38.09126], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([30.76774], dtype=float32), array([19.], dtype=float32))
# ************************************
# pred, real
# (array([32.382477], dtype=float32), array([83.], dtype=float32))
# ************************************
# pred, real
# (array([30.506666], dtype=float32), array([70.], dtype=float32))
# ************************************
# pred, real
# (array([26.923338], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([42.21483], dtype=float32), array([53.], dtype=float32))
# ************************************
# pred, real
# (array([37.929295], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([36.98323], dtype=float32), array([50.], dtype=float32))
# ************************************
# pred, real
# (array([34.757866], dtype=float32), array([55.], dtype=float32))
# ************************************
# pred, real
# (array([39.048325], dtype=float32), array([63.], dtype=float32))
# ************************************
# pred, real
# (array([28.925283], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([40.307796], dtype=float32), array([40.], dtype=float32))
# ************************************
# pred, real
# (array([27.871836], dtype=float32), array([55.], dtype=float32))
# ************************************
# pred, real
# (array([36.724327], dtype=float32), array([57.], dtype=float32))
# ************************************
# pred, real
# (array([30.20922], dtype=float32), array([18.], dtype=float32))
# ************************************
# pred, real
# (array([31.346102], dtype=float32), array([21.], dtype=float32))
# ************************************
# pred, real
# (array([32.883484], dtype=float32), array([62.], dtype=float32))
# ************************************
# pred, real
# (array([39.636192], dtype=float32), array([55.], dtype=float32))
# ************************************
# pred, real
# (array([41.36746], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([31.570383], dtype=float32), array([28.], dtype=float32))
# ************************************
# pred, real
# (array([27.325386], dtype=float32), array([2.], dtype=float32))
# ************************************
# pred, real
# (array([27.573801], dtype=float32), array([11.], dtype=float32))
# ************************************
# pred, real
# (array([37.06116], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([23.735222], dtype=float32), array([61.], dtype=float32))
# ************************************
# pred, real
# (array([23.83787], dtype=float32), array([10.], dtype=float32))
# ************************************
# pred, real
# (array([31.663454], dtype=float32), array([36.], dtype=float32))
# ************************************
# pred, real
# (array([33.66165], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([24.369556], dtype=float32), array([16.], dtype=float32))
# ************************************
# pred, real
# (array([39.373096], dtype=float32), array([57.], dtype=float32))
# ************************************
# pred, real
# (array([36.789513], dtype=float32), array([51.], dtype=float32))
# ************************************
# pred, real
# (array([35.12691], dtype=float32), array([20.], dtype=float32))
# ************************************
# pred, real
# (array([29.08558], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([31.127964], dtype=float32), array([65.], dtype=float32))
# ************************************
# pred, real
# (array([36.63212], dtype=float32), array([22.], dtype=float32))
# ************************************
# pred, real
# (array([31.973143], dtype=float32), array([64.], dtype=float32))
# ************************************
# pred, real
# (array([31.943695], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([25.69563], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([28.242537], dtype=float32), array([48.], dtype=float32))
# ************************************
# pred, real
# (array([34.346535], dtype=float32), array([75.], dtype=float32))
# ************************************
# pred, real
# (array([33.049896], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([34.872044], dtype=float32), array([42.], dtype=float32))
# ************************************
# pred, real
# (array([32.187893], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([21.359684], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([34.38718], dtype=float32), array([35.], dtype=float32))
# ************************************
# pred, real
# (array([38.51616], dtype=float32), array([82.], dtype=float32))
# ************************************
# pred, real
# (array([31.942762], dtype=float32), array([51.], dtype=float32))
# ************************************
# pred, real
# (array([35.037228], dtype=float32), array([30.], dtype=float32))
# ************************************
# pred, real
# (array([28.501024], dtype=float32), array([21.], dtype=float32))
# ************************************
# pred, real
# (array([36.460274], dtype=float32), array([27.], dtype=float32))
# ************************************
# pred, real
# (array([35.287323], dtype=float32), array([52.], dtype=float32))
# ************************************
# pred, real
# (array([34.926514], dtype=float32), array([55.], dtype=float32))
# ************************************
# pred, real
# (array([33.125927], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([39.142033], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([21.96726], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.038235], dtype=float32), array([52.], dtype=float32))
# ************************************
# pred, real
# (array([39.702354], dtype=float32), array([33.], dtype=float32))
# ************************************
# pred, real
# (array([33.086502], dtype=float32), array([66.], dtype=float32))
# ************************************
# pred, real
# (array([29.139662], dtype=float32), array([48.], dtype=float32))
# ************************************
# pred, real
# (array([37.305153], dtype=float32), array([41.], dtype=float32))
# ************************************
# pred, real
# (array([36.440582], dtype=float32), array([57.], dtype=float32))
# ************************************
# pred, real
# (array([33.103336], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([33.094257], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([28.918774], dtype=float32), array([9.], dtype=float32))
# ************************************
# pred, real
# (array([39.40483], dtype=float32), array([63.], dtype=float32))
# ************************************
# pred, real
# (array([45.14861], dtype=float32), array([38.], dtype=float32))
# ************************************
# pred, real
# (array([27.075243], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.921803], dtype=float32), array([51.], dtype=float32))
# ************************************
# pred, real
# (array([35.1304], dtype=float32), array([39.], dtype=float32))
# ************************************
# pred, real
# (array([37.52213], dtype=float32), array([59.], dtype=float32))
# ************************************
# pred, real
# (array([37.243748], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([23.287743], dtype=float32), array([53.], dtype=float32))
# ************************************
# pred, real
# (array([33.385727], dtype=float32), array([50.], dtype=float32))
# ************************************
# pred, real
# (array([32.58244], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.928802], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([33.661884], dtype=float32), array([41.], dtype=float32))
# ************************************
# pred, real
# (array([35.012115], dtype=float32), array([34.], dtype=float32))
# ************************************
# pred, real
# (array([25.736889], dtype=float32), array([6.], dtype=float32))
# ************************************
# pred, real
# (array([39.477116], dtype=float32), array([74.], dtype=float32))
# ************************************
# pred, real
# (array([34.93715], dtype=float32), array([30.], dtype=float32))
# ************************************
# pred, real
# (array([36.880077], dtype=float32), array([86.], dtype=float32))
# ************************************
# pred, real
# (array([37.37799], dtype=float32), array([39.], dtype=float32))
# ************************************
# pred, real
# (array([32.6726], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([35.208023], dtype=float32), array([42.], dtype=float32))
# ************************************
# pred, real
# (array([34.67689], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([32.706863], dtype=float32), array([39.], dtype=float32))
# ************************************
# pred, real
# (array([38.604588], dtype=float32), array([68.], dtype=float32))
# ************************************
# pred, real
# (array([33.56856], dtype=float32), array([27.], dtype=float32))
# ************************************
# pred, real
# (array([33.25081], dtype=float32), array([53.], dtype=float32))
# ************************************
# pred, real
# (array([34.84129], dtype=float32), array([58.], dtype=float32))
# ************************************
# pred, real
# (array([36.334145], dtype=float32), array([77.], dtype=float32))
# ************************************
# pred, real
# (array([35.39645], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([35.51677], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([34.52846], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([39.711754], dtype=float32), array([63.], dtype=float32))
# ************************************
# pred, real
# (array([33.855316], dtype=float32), array([71.], dtype=float32))
# ************************************
# pred, real
# (array([35.927437], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([37.67785], dtype=float32), array([80.], dtype=float32))
# ************************************
# pred, real
# (array([33.93152], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.2473], dtype=float32), array([33.], dtype=float32))
# ************************************
# pred, real
# (array([39.436535], dtype=float32), array([71.], dtype=float32))
# ************************************
# pred, real
# (array([25.201925], dtype=float32), array([53.], dtype=float32))
# ************************************
# pred, real
# (array([35.012676], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([35.758507], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([41.31434], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([35.754883], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([33.321434], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([33.721786], dtype=float32), array([42.], dtype=float32))
# ************************************
# pred, real
# (array([41.213024], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([34.715397], dtype=float32), array([64.], dtype=float32))
# ************************************
# pred, real
# (array([34.649727], dtype=float32), array([35.], dtype=float32))
# ************************************
# pred, real
# (array([21.255333], dtype=float32), array([16.], dtype=float32))
# ************************************
# pred, real
# (array([34.672863], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([35.243057], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([27.428978], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.888866], dtype=float32), array([42.], dtype=float32))
# ************************************
# pred, real
# (array([36.769775], dtype=float32), array([35.], dtype=float32))
# ************************************
# pred, real
# (array([37.9461], dtype=float32), array([12.], dtype=float32))
# ************************************
# pred, real
# (array([32.627193], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([38.05614], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([40.912495], dtype=float32), array([19.], dtype=float32))
# ************************************
# pred, real
# (array([33.089752], dtype=float32), array([18.], dtype=float32))
# ************************************
# pred, real
# (array([33.405422], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.936817], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([35.97378], dtype=float32), array([41.], dtype=float32))
# ************************************
# pred, real
# (array([36.92742], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([29.814213], dtype=float32), array([15.], dtype=float32))
# ************************************
# pred, real
# (array([33.457157], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([42.354324], dtype=float32), array([58.], dtype=float32))
# ************************************
# pred, real
# (array([30.188961], dtype=float32), array([13.], dtype=float32))
# ************************************
# pred, real
# (array([24.783318], dtype=float32), array([58.], dtype=float32))
# ************************************
# pred, real
# (array([29.249498], dtype=float32), array([34.], dtype=float32))
# ************************************
# pred, real
# (array([26.598177], dtype=float32), array([2.], dtype=float32))
# ************************************
# pred, real
# (array([30.078205], dtype=float32), array([19.], dtype=float32))
# ************************************
# pred, real
# (array([36.067223], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([44.70673], dtype=float32), array([30.], dtype=float32))
# ************************************
# pred, real
# (array([32.26228], dtype=float32), array([7.], dtype=float32))
# ************************************
# pred, real
# (array([34.602158], dtype=float32), array([64.], dtype=float32))
# ************************************
# pred, real
# (array([36.750084], dtype=float32), array([39.], dtype=float32))
# ************************************
# pred, real
# (array([35.449924], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([25.610777], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([33.451424], dtype=float32), array([48.], dtype=float32))
# ************************************
# pred, real
# (array([31.87415], dtype=float32), array([1.], dtype=float32))
# ************************************
# pred, real
# (array([28.053984], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([22.785782], dtype=float32), array([52.], dtype=float32))
# ************************************
# pred, real
# (array([35.86195], dtype=float32), array([41.], dtype=float32))
# ************************************
# pred, real
# (array([39.144985], dtype=float32), array([58.], dtype=float32))
# ************************************
# pred, real
# (array([41.67299], dtype=float32), array([50.], dtype=float32))
# ************************************
# pred, real
# (array([32.235672], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([30.811348], dtype=float32), array([59.], dtype=float32))
# ************************************
# pred, real
# (array([32.03815], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([34.1083], dtype=float32), array([55.], dtype=float32))
# ************************************
# pred, real
# (array([22.873487], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.12102], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([27.116474], dtype=float32), array([39.], dtype=float32))
# ************************************
# pred, real
# (array([35.662323], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([39.318756], dtype=float32), array([50.], dtype=float32))
# ************************************
# pred, real
# (array([31.583376], dtype=float32), array([27.], dtype=float32))
# ************************************
# pred, real
# (array([28.040976], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([21.854326], dtype=float32), array([29.], dtype=float32))
# ************************************
# pred, real
# (array([37.674915], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([38.037663], dtype=float32), array([70.], dtype=float32))
# ************************************
# pred, real
# (array([32.711815], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([41.06707], dtype=float32), array([77.], dtype=float32))
# ************************************
# pred, real
# (array([37.685844], dtype=float32), array([93.], dtype=float32))
# ************************************
# pred, real
# (array([34.350033], dtype=float32), array([59.], dtype=float32))
# ************************************
# pred, real
# (array([37.525], dtype=float32), array([65.], dtype=float32))
# ************************************
# pred, real
# (array([31.433084], dtype=float32), array([41.], dtype=float32))
# ************************************
# pred, real
# (array([32.96957], dtype=float32), array([27.], dtype=float32))
# ************************************
# pred, real
# (array([28.358599], dtype=float32), array([19.], dtype=float32))
# ************************************
# pred, real
# (array([33.986664], dtype=float32), array([26.], dtype=float32))
# ************************************
# pred, real
# (array([32.177948], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([34.162983], dtype=float32), array([32.], dtype=float32))
# ************************************
# pred, real
# (array([20.118767], dtype=float32), array([19.], dtype=float32))
# ************************************
# pred, real
# (array([35.216778], dtype=float32), array([48.], dtype=float32))
# ************************************
# pred, real
# (array([24.880156], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([28.7607], dtype=float32), array([58.], dtype=float32))
# ************************************
# pred, real
# (array([34.7241], dtype=float32), array([55.], dtype=float32))
# ************************************
# pred, real
# (array([41.447674], dtype=float32), array([33.], dtype=float32))
# ************************************
# pred, real
# (array([35.271442], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([33.707333], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.920563], dtype=float32), array([40.], dtype=float32))
# ************************************
# pred, real
# (array([39.791576], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([42.251854], dtype=float32), array([59.], dtype=float32))
# ************************************
# pred, real
# (array([32.0952], dtype=float32), array([64.], dtype=float32))
# ************************************
# pred, real
# (array([34.017963], dtype=float32), array([47.], dtype=float32))
# ************************************
# pred, real
# (array([36.19768], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([34.20288], dtype=float32), array([52.], dtype=float32))
# ************************************
# pred, real
# (array([39.77019], dtype=float32), array([51.], dtype=float32))
# ************************************
# pred, real
# (array([29.999416], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([33.78392], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([37.345554], dtype=float32), array([47.], dtype=float32))
# ************************************
# pred, real
# (array([22.587576], dtype=float32), array([22.], dtype=float32))
# ************************************
# pred, real
# (array([27.03548], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([38.156166], dtype=float32), array([54.], dtype=float32))
# ************************************
# pred, real
# (array([32.216602], dtype=float32), array([46.], dtype=float32))
# ************************************
# pred, real
# (array([34.323555], dtype=float32), array([63.], dtype=float32))
# ************************************
# pred, real
# (array([35.43608], dtype=float32), array([21.], dtype=float32))
# ************************************
# pred, real
# (array([37.8912], dtype=float32), array([65.], dtype=float32))
# ************************************
# pred, real
# (array([34.190296], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([31.985035], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([36.055756], dtype=float32), array([62.], dtype=float32))
# ************************************
# pred, real
# (array([38.47228], dtype=float32), array([40.], dtype=float32))
# ************************************
# pred, real
# (array([29.297338], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([36.584335], dtype=float32), array([34.], dtype=float32))
# ************************************
# pred, real
# (array([40.224514], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([40.196163], dtype=float32), array([57.], dtype=float32))
# ************************************
# pred, real
# (array([33.656273], dtype=float32), array([26.], dtype=float32))
# ************************************
# pred, real
# (array([32.751305], dtype=float32), array([62.], dtype=float32))
# ************************************
# pred, real
# (array([33.811882], dtype=float32), array([60.], dtype=float32))
# ************************************
# pred, real
# (array([43.853447], dtype=float32), array([35.], dtype=float32))
# ************************************
# pred, real
# (array([32.630672], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([36.090942], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([26.870913], dtype=float32), array([17.], dtype=float32))
# ************************************
# pred, real
# (array([18.341301], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([30.627668], dtype=float32), array([1.], dtype=float32))
# ************************************
# pred, real
# (array([36.914856], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([23.213799], dtype=float32), array([13.], dtype=float32))
# ************************************
# pred, real
# (array([33.6752], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([29.344292], dtype=float32), array([50.], dtype=float32))
# ************************************
# pred, real
# (array([38.536198], dtype=float32), array([8.], dtype=float32))
# ************************************
# pred, real
# (array([37.56775], dtype=float32), array([42.], dtype=float32))
# ************************************
# pred, real
# (array([32.12014], dtype=float32), array([54.], dtype=float32))
# ************************************
# pred, real
# (array([22.389402], dtype=float32), array([9.], dtype=float32))
# ************************************
# pred, real
# (array([41.284405], dtype=float32), array([36.], dtype=float32))
# ************************************
# pred, real
# (array([42.91657], dtype=float32), array([57.], dtype=float32))
# ************************************
# pred, real
# (array([39.061142], dtype=float32), array([16.], dtype=float32))
# ************************************
# pred, real
# (array([39.0379], dtype=float32), array([41.], dtype=float32))
# ************************************
# pred, real
# (array([31.00154], dtype=float32), array([31.], dtype=float32))
# ************************************
# pred, real
# (array([35.139023], dtype=float32), array([4.], dtype=float32))
# ************************************
# pred, real
# (array([33.823086], dtype=float32), array([25.], dtype=float32))
# ************************************
# pred, real
# (array([33.57481], dtype=float32), array([22.], dtype=float32))
# ************************************
# pred, real
# (array([33.568924], dtype=float32), array([42.], dtype=float32))
# ************************************
# pred, real
# (array([31.855469], dtype=float32), array([89.], dtype=float32))
# ************************************
# pred, real
# (array([37.356174], dtype=float32), array([68.], dtype=float32))
# ************************************
# pred, real
# (array([39.28535], dtype=float32), array([59.], dtype=float32))
# ************************************
# pred, real
# (array([24.839304], dtype=float32), array([12.], dtype=float32))
# ************************************
# pred, real
# (array([35.377716], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([34.356007], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([36.53967], dtype=float32), array([42.], dtype=float32))
# ************************************
# pred, real
# (array([41.636818], dtype=float32), array([33.], dtype=float32))
# ************************************
# pred, real
# (array([34.548553], dtype=float32), array([71.], dtype=float32))
# ************************************
# pred, real
# (array([39.06589], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([36.004578], dtype=float32), array([73.], dtype=float32))
# ************************************
# pred, real
# (array([25.630117], dtype=float32), array([14.], dtype=float32))
# ************************************
# pred, real
# (array([35.100018], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([33.949734], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([37.182686], dtype=float32), array([40.], dtype=float32))
# ************************************
# pred, real
# ...
# ************************************
# pred, real
# (array([40.60503], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([38.793877], dtype=float32), array([48.], dtype=float32))
# ************************************
# pred, real
# (array([33.35182], dtype=float32), array([27.], dtype=float32))
# ************************************
# pred, real
# (array([30.632141], dtype=float32), array([15.], dtype=float32))
# ************************************
# pred, real
# (array([36.981102], dtype=float32), array([54.], dtype=float32))
# ************************************
# pred, real
# (array([38.83985], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([28.946983], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([33.147224], dtype=float32), array([8.], dtype=float32))
# ************************************
# pred, real
# (array([31.749334], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([25.834894], dtype=float32), array([20.], dtype=float32))
# ************************************
# pred, real
# (array([39.589073], dtype=float32), array([57.], dtype=float32))
# ************************************
# pred, real
# (array([32.042496], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.33333], dtype=float32), array([31.], dtype=float32))
# ************************************
# pred, real
# (array([33.080387], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([35.01123], dtype=float32), array([21.], dtype=float32))
# ************************************
# pred, real
# (array([38.663044], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([21.790491], dtype=float32), array([28.], dtype=float32))
# ************************************
# pred, real
# (array([30.469864], dtype=float32), array([38.], dtype=float32))
# ************************************
# pred, real
# (array([35.36493], dtype=float32), array([1.], dtype=float32))
# ************************************
# pred, real
# (array([37.063343], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([22.767065], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([34.41673], dtype=float32), array([38.], dtype=float32))
# ************************************
# pred, real
# (array([23.176224], dtype=float32), array([38.], dtype=float32))
# ************************************
# pred, real
# (array([33.226574], dtype=float32), array([76.], dtype=float32))
# ************************************
# pred, real
# (array([33.53111], dtype=float32), array([54.], dtype=float32))
# ************************************
# pred, real
# (array([32.578316], dtype=float32), array([57.], dtype=float32))
# ************************************
# pred, real
# (array([29.430439], dtype=float32), array([28.], dtype=float32))
# ************************************
# pred, real
# (array([29.833347], dtype=float32), array([42.], dtype=float32))
# ************************************
# pred, real
# (array([31.714241], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([33.475716], dtype=float32), array([40.], dtype=float32))
# ************************************
# pred, real
# (array([36.08116], dtype=float32), array([30.], dtype=float32))
# ************************************
# pred, real
# (array([23.550766], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([35.13879], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([30.931778], dtype=float32), array([28.], dtype=float32))
# ************************************
# pred, real
# (array([38.302814], dtype=float32), array([51.], dtype=float32))
# ************************************
# pred, real
# (array([31.977745], dtype=float32), array([25.], dtype=float32))
# ************************************
# pred, real
# (array([30.469408], dtype=float32), array([47.], dtype=float32))
# ************************************
# pred, real
# (array([35.940132], dtype=float32), array([28.], dtype=float32))
# ************************************
# pred, real
# (array([37.603905], dtype=float32), array([1.], dtype=float32))
# ************************************
# pred, real
# (array([38.387146], dtype=float32), array([42.], dtype=float32))
# ************************************
# pred, real
# (array([29.67057], dtype=float32), array([31.], dtype=float32))
# ************************************
# pred, real
# (array([37.405758], dtype=float32), array([47.], dtype=float32))
# ************************************
# pred, real
# (array([32.42642], dtype=float32), array([30.], dtype=float32))
# ************************************
# pred, real
# (array([38.09523], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([41.317604], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([36.02695], dtype=float32), array([38.], dtype=float32))
# ************************************
# pred, real
# (array([24.719252], dtype=float32), array([16.], dtype=float32))
# ************************************
# pred, real
# (array([31.804296], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([28.769817], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([24.88615], dtype=float32), array([13.], dtype=float32))
# ************************************
# pred, real
# (array([33.85499], dtype=float32), array([88.], dtype=float32))
# ************************************
# pred, real
# (array([34.70928], dtype=float32), array([30.], dtype=float32))
# ************************************
# pred, real
# (array([34.92052], dtype=float32), array([22.], dtype=float32))
# ************************************
# pred, real
# (array([27.707516], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([37.281887], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([33.12401], dtype=float32), array([17.], dtype=float32))
# ************************************
# pred, real
# (array([32.400986], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([32.99604], dtype=float32), array([34.], dtype=float32))
# ************************************
# pred, real
# (array([31.80555], dtype=float32), array([3.], dtype=float32))
# ************************************
# pred, real
# (array([40.456814], dtype=float32), array([2.], dtype=float32))
# ************************************
# pred, real
# (array([30.743568], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([20.776876], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([26.386574], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([28.184204], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.75073], dtype=float32), array([62.], dtype=float32))
# ************************************
# pred, real
# (array([32.479008], dtype=float32), array([59.], dtype=float32))
# ************************************
# pred, real
# (array([40.42064], dtype=float32), array([50.], dtype=float32))
# ************************************
# pred, real
# (array([35.805576], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([31.943874], dtype=float32), array([60.], dtype=float32))
# ************************************
# pred, real
# (array([33.123215], dtype=float32), array([19.], dtype=float32))
# ************************************
# pred, real
# (array([28.62616], dtype=float32), array([22.], dtype=float32))
# ************************************
# pred, real
# (array([40.76765], dtype=float32), array([46.], dtype=float32))
# ************************************
# pred, real
# (array([33.216564], dtype=float32), array([50.], dtype=float32))
# ************************************
# pred, real
# (array([37.259037], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([34.13109], dtype=float32), array([39.], dtype=float32))
# ************************************
# pred, real
# (array([25.657007], dtype=float32), array([35.], dtype=float32))
# ************************************
# pred, real
# (array([25.963842], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([32.552574], dtype=float32), array([37.], dtype=float32))
# ************************************
# pred, real
# (array([40.214104], dtype=float32), array([66.], dtype=float32))
# ************************************
# pred, real
# (array([30.891167], dtype=float32), array([82.], dtype=float32))
# ************************************
# pred, real
# (array([42.2401], dtype=float32), array([34.], dtype=float32))
# ************************************
# pred, real
# (array([37.00576], dtype=float32), array([40.], dtype=float32))
# ************************************
# pred, real
# (array([32.75237], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([28.048418], dtype=float32), array([21.], dtype=float32))
# ************************************
# pred, real
# (array([29.892525], dtype=float32), array([52.], dtype=float32))
# ************************************
# pred, real
# (array([35.285324], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([27.056456], dtype=float32), array([29.], dtype=float32))
# ************************************
# pred, real
# (array([29.417778], dtype=float32), array([51.], dtype=float32))
# ************************************
# pred, real
# (array([25.096928], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([35.103413], dtype=float32), array([36.], dtype=float32))
# ************************************
# pred, real
# (array([40.828403], dtype=float32), array([59.], dtype=float32))
# ************************************
# pred, real
# (array([32.505775], dtype=float32), array([54.], dtype=float32))
# ************************************
# pred, real
# (array([29.21845], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([39.19864], dtype=float32), array([43.], dtype=float32))
# ************************************
# pred, real
# (array([30.901432], dtype=float32), array([80.], dtype=float32))
# ************************************
# pred, real
# (array([21.819668], dtype=float32), array([7.], dtype=float32))
# ************************************
# pred, real
# (array([34.145557], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([24.96739], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([21.365355], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([34.898163], dtype=float32), array([77.], dtype=float32))
# ************************************
# pred, real
# (array([36.83149], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([34.086163], dtype=float32), array([46.], dtype=float32))
# ************************************
# pred, real
# (array([34.65391], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([25.675735], dtype=float32), array([17.], dtype=float32))
# ************************************
# pred, real
# (array([30.756664], dtype=float32), array([44.], dtype=float32))
# ************************************
# pred, real
# (array([31.107767], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([37.346306], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([32.1115], dtype=float32), array([21.], dtype=float32))
# ************************************
# pred, real
# (array([30.487078], dtype=float32), array([19.], dtype=float32))
# ************************************
# pred, real
# (array([34.43887], dtype=float32), array([33.], dtype=float32))
# ************************************
# pred, real
# (array([28.316757], dtype=float32), array([56.], dtype=float32))
# ************************************
# pred, real
# (array([38.26577], dtype=float32), array([45.], dtype=float32))
# ************************************
# pred, real
# (array([25.445919], dtype=float32), array([2.], dtype=float32))
# ************************************
# pred, real
# (array([34.70553], dtype=float32), array([23.], dtype=float32))
# ************************************
# pred, real
# (array([36.42388], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([40.135754], dtype=float32), array([88.], dtype=float32))
# ************************************
# pred, real
# (array([33.898994], dtype=float32), array([67.], dtype=float32))
# ************************************
# pred, real
# (array([23.007942], dtype=float32), array([31.], dtype=float32))
# ************************************
# pred, real
# (array([43.388695], dtype=float32), array([46.], dtype=float32))
# ************************************
# pred, real
# (array([36.4263], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([30.827322], dtype=float32), array([24.], dtype=float32))
# ************************************
# pred, real
# (array([23.351332], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([23.788086], dtype=float32), array([17.], dtype=float32))
# ************************************
# pred, real
# (array([23.925625], dtype=float32), array([19.], dtype=float32))
# ************************************
# pred, real
# (array([36.246067], dtype=float32), array([1.], dtype=float32))
# ************************************
# pred, real
# (array([31.677368], dtype=float32), array([29.], dtype=float32))
# ************************************
# pred, real
# (array([33.224365], dtype=float32), array([22.], dtype=float32))
# ************************************
# pred, real
# (array([34.408363], dtype=float32), array([38.], dtype=float32))
# ************************************
# pred, real
# (array([38.595203], dtype=float32), array([49.], dtype=float32))
# ************************************
# pred, real
# (array([26.619738], dtype=float32), array([22.], dtype=float32))
# ************************************
# pred, real
# (array([38.09027], dtype=float32), array([67.], dtype=float32))
# ************************************
# pred, real
# (array([33.93152], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([31.610037], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([33.310665], dtype=float32), array([46.], dtype=float32))
# ************************************
# pred, real
# (array([42.76782], dtype=float32), array([66.], dtype=float32))
# ************************************
# pred, real
# (array([39.270294], dtype=float32), array([22.], dtype=float32))
# ************************************
# pred, real
# (array([43.238857], dtype=float32), array([51.], dtype=float32))
# ************************************
# pred, real
# (array([35.068325], dtype=float32), array([0.], dtype=float32))
# ************************************
# pred, real
# (array([26.66398], dtype=float32), array([25.], dtype=float32))
# ************************************
# pred, real
# (array([22.988863], dtype=float32), array([18.], dtype=float32))
# ************************************
# pred, real
# (array([40.521774], dtype=float32), array([85.], dtype=float32))
# ************************************
# pred, real
# (array([42.78628], dtype=float32), array([44.], dtype=float32))

# %% [markdown]
# # Deploy Model

# %%
model.eval()

dummy_input = torch.randn(1, 11)

input_names  = ["input1"]
output_names = ["output1"]

torch.onnx.export(
        model,                        # Model
        dummy_input,                  # To tell the size of the imput vector
        "DLnet_WineData.onnx",        # Name of the file created
        verbose=False,
        input_names = input_names,
        output_names = output_names

)

# The trick is that we have to look at the version and if it is compatible
# With our HTML and JS version
# Out:
# /tmp/ipython-input-2945923537.py:8: DeprecationWarning: You are using the legacy TorchScript-based ONNX export. Starting in PyTorch 2.9, the new torch.export-based ONNX exporter will be the default. To switch now, set dynamo=True in torch.onnx.export. This new exporter supports features like exporting LLMs with DynamicCache. We encourage you to try it and share feedback to help improve the experience. Learn more about the new export logic: https://pytorch.org/docs/stable/onnx_dynamo.html. For exporting control flow: https://pytorch.org/tutorials/beginner/onnx/export_control_flow_model_to_onnx_tutorial.html.
#   torch.onnx.export(

# %% [markdown]
# # **XGBoost**

# %%
# Read the notes.
# Usually better interpolating (worse at extrapolating)

regressor = xgb.XGBRegressor(

        n_estimators=100,
        reg_lambda=1,
        gamma=0,
        max_depth=3
)

# %%
regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred.shape
# Out:
# (22800,)

# %%
y_pred
# Out:
# array([38.430115, 34.318707, 31.000582, ..., 17.432095, 41.154545,
#        42.561676], dtype=float32)

# %%
# Evaluate with XGBoost

r2_score(y_test, y_pred)
# Out:
# 0.10769766569137573

# %%
# Next step will be to deploy it

# %% [markdown]
# # **Classification**
